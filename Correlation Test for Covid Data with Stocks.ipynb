# %% [markdown]
# # Pearson’s Correlation Coefficient

# %% [markdown]
# ### Assumptions
#
# -Observations in each sample are independent and identically distributed (iid).
#
# -Observations in each sample are normally distributed.
#
# -Observations in each sample have the same variance.
#
#
# ### Interpretation
#
# -H0: the two samples are independent.
#
# -H1: there is a dependency between the samples.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('merge2.xlsx')

# %%
df['Date'] = pd.to_datetime(df['Unnamed: 0'])

# %%
df.set_index('Date', drop=True, inplace=True)

# %%
df.drop(axis=1, columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-30  1690.099976  1709.699951  1665.300049  1674.900024  1653.261841
# 2020-01-31  1694.000000  1694.000000  1655.000000  1665.400024  1643.884644
# 2020-02-03  1645.000000  1678.300049  1611.250000  1646.349976  1625.080688
# 2020-02-04  1520.000000  1522.000000  1425.050049  1447.550049  1428.848999
# 2020-02-05  1434.099976  1538.800049  1365.000000  1376.500000  1358.716919
# ...                 ...          ...          ...          ...          ...
# 2020-11-12  1442.000000  1468.750000  1413.000000  1430.250000  1430.250000
# 2020-11-13  1427.000000  1435.000000  1410.000000  1428.349976  1428.349976
# 2020-11-17  1450.000000  1454.349976  1432.500000  1444.050049  1444.050049
# 2020-11-18  1442.000000  1449.050049  1421.000000  1429.000000  1429.000000
# 2020-11-19  1430.000000  1497.900024  1430.000000  1484.599976  1484.599976
#
# ...

# %%
x = df['Close']
y1 = df['Daily Confirmed']
y2 = df['Total Confirmed']
y3 = df['Daily Recovered']
y4 = df['Total Recovered']
y5 = df['Daily Deceased']
y6 = df['Total Deceased']

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.heatmap(df.corr(method='pearson'), annot = True, vmin=-1, vmax=1, center= 0)
