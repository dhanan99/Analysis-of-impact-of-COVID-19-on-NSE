# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
path20="/content/drive/My Drive/bitsproj/CIPLA.NS.csv"
path19="/content/drive/My Drive/bitsproj/CIPLA.NS19.csv"

# %%
df20 = pd.read_csv(path20)
df19 = pd.read_csv(path19)

# %%
df20.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2020-03-16  416.000000  423.899994  ...  396.399994  395.373047  5394603
# 1  2020-03-17  397.000000  422.000000  ...  401.750000  400.709198  2989674
# 2  2020-03-18  411.799988  411.799988  ...  386.000000  385.000000  4200456
# 3  2020-03-19  374.799988  390.750000  ...  374.700012  374.700012  2926091
# 4  2020-03-20  379.799988  399.799988  ...  392.799988  392.799988  4718358
#
# [5 rows x 7 columns]

# %%
df20.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  146.000000  146.000000  146.000000  146.000000  146.000000  1.460000e+02
# mean   651.905137  663.822947  640.283903  650.046574  650.025562  8.747664e+06
# std    107.984350  106.378569  107.016631  107.158102  107.208579  6.623319e+06
# min    370.000000  390.750000  362.899994  374.700012  374.700012  2.161524e+06
# 25%    604.587509  614.250000  590.124985  598.774979  598.774979  5.046351e+06
# 50%    646.824982  653.899994  636.500000  643.274994  643.274994  6.769608e+06
# 75%    742.012512  753.000000  728.025009  737.824997  737.824997  1.024491e+07
# max    813.000000  829.049988  800.349976  813.650024  813.650024  5.689521e+07

# %%
df19.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2019-03-15  534.099976  535.400024  ...  532.599976  528.155457  2019240
# 1  2019-03-18  533.049988  535.799988  ...  534.500000  530.039612  1266863
# 2  2019-03-19  537.150024  537.700012  ...  533.650024  529.196716   874797
# 3  2019-03-20  532.000000  534.799988  ...  533.250000  528.800049  1255306
# 4  2019-03-22  534.900024  539.000000  ...  526.799988  522.403870  1579084
#
# [5 rows x 7 columns]

# %%
df19.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  139.000000  139.000000  139.000000  139.000000  139.000000  1.390000e+02
# mean   520.725541  526.615110  513.141727  519.762947  516.348559  2.366718e+06
# std     44.754809   45.076150   45.820709   45.122881   43.647448  2.011827e+06
# min    408.299988  419.950012  389.549988  408.250000  407.192352  5.654140e+05
# 25%    477.975006  482.100006  471.350006  475.800003  474.567368  1.267795e+06
# 50%    534.900024  540.000000  529.000000  533.700012  529.246338  1.808363e+06
# 75%    556.000000  562.549988  550.024994  555.649994  551.013092  2.583513e+06
# max    579.000000  586.000000  571.500000  578.700012  573.870789  1.735478e+07

# %%
df20.shape
# Out:
# (146, 7)

# %%
df19['newda'] = [df19['Date'][i][5:] for i in range(139)]
df20['newda'] = [df20['Date'][i][5:] for i in range(146)]
df19.head()
# Out:
#          Date        Open        High  ...   Adj Close   Volume  newda
# 0  2019-03-15  534.099976  535.400024  ...  528.155457  2019240  03-15
# 1  2019-03-18  533.049988  535.799988  ...  530.039612  1266863  03-18
# 2  2019-03-19  537.150024  537.700012  ...  529.196716   874797  03-19
# 3  2019-03-20  532.000000  534.799988  ...  528.800049  1255306  03-20
# 4  2019-03-22  534.900024  539.000000  ...  522.403870  1579084  03-22
#
# [5 rows x 8 columns]

# %%
df_in = pd.merge(df19,df20,on='newda',how='inner')
df_in.head()
# Out:
#        Date_x      Open_x      High_x  ...     Close_y  Adj Close_y  Volume_y
# 0  2019-03-18  533.049988  535.799988  ...  386.000000   385.000000   4200456
# 1  2019-03-19  537.150024  537.700012  ...  374.700012   374.700012   2926091
# 2  2019-03-20  532.000000  534.799988  ...  392.799988   392.799988   4718358
# 3  2019-03-25  525.599976  528.700012  ...  376.450012   376.450012   6418955
# 4  2019-03-26  528.500000  532.500000  ...  386.149994   386.149994   4291225
#
# [5 rows x 15 columns]

# %%
ndf19=pd.DataFrame(df_in,columns=['Date_x','Open_x','High_x',	'Low_x','Close_x','Adj Close_x','Volume_x'])
ndf19.head()
# Out:
#        Date_x      Open_x      High_x  ...     Close_x  Adj Close_x  Volume_x
# 0  2019-03-18  533.049988  535.799988  ...  534.500000   530.039612   1266863
# 1  2019-03-19  537.150024  537.700012  ...  533.650024   529.196716    874797
# 2  2019-03-20  532.000000  534.799988  ...  533.250000   528.800049   1255306
# 3  2019-03-25  525.599976  528.700012  ...  526.849976   522.453430   1874898
# 4  2019-03-26  528.500000  532.500000  ...  529.299988   524.882996   3044792
#
# [5 rows x 7 columns]

# %%
ndf20=pd.DataFrame(df_in,columns=['Date_y','Open_y','High_y',	'Low_y','Close_y','Adj Close_y','Volume_y'])
ndf20.head()
# Out:
#        Date_y      Open_y      High_y  ...     Close_y  Adj Close_y  Volume_y
# 0  2020-03-18  411.799988  411.799988  ...  386.000000   385.000000   4200456
# 1  2020-03-19  374.799988  390.750000  ...  374.700012   374.700012   2926091
# 2  2020-03-20  379.799988  399.799988  ...  392.799988   392.799988   4718358
# 3  2020-03-25  378.000000  394.899994  ...  376.450012   376.450012   6418955
# 4  2020-03-26  383.000000  394.700012  ...  386.149994   386.149994   4291225
#
# [5 rows x 7 columns]

# %%
df_in.plot(x='newda',y=["Close_x","Close_y"],figsize=(15,8))
plt.legend(fontsize=20)

# %%
ndf19["PriceDiff"] = ndf19["Close_x"].shift(-1)-ndf19["Close_x"]

# %%
ndf19["return"] = ndf19["PriceDiff"]/ndf19["Close_x"]

# %%
ndf20["PriceDiff"] = ndf20["Close_y"].shift(-1)-ndf20["Close_y"]

# %%
ndf20["return"] = ndf20["PriceDiff"]/ndf20["Close_y"]

# %%
ndf19.head()
# Out:
#        Date_x      Open_x      High_x  ...  Volume_x  PriceDiff    return
# 0  2019-03-18  533.049988  535.799988  ...   1266863  -0.849976 -0.001590
# 1  2019-03-19  537.150024  537.700012  ...    874797  -0.400024 -0.000750
# 2  2019-03-20  532.000000  534.799988  ...   1255306  -6.400024 -0.012002
# 3  2019-03-25  525.599976  528.700012  ...   1874898   2.450012  0.004650
# 4  2019-03-26  528.500000  532.500000  ...   3044792  -3.799988 -0.007179
#
# [5 rows x 9 columns]

# %%
ndf20.head()
# Out:
#        Date_y      Open_y      High_y  ...  Volume_y  PriceDiff    return
# 0  2020-03-18  411.799988  411.799988  ...   4200456 -11.299988 -0.029275
# 1  2020-03-19  374.799988  390.750000  ...   2926091  18.099976  0.048305
# 2  2020-03-20  379.799988  399.799988  ...   4718358 -16.349976 -0.041624
# 3  2020-03-25  378.000000  394.899994  ...   6418955   9.699982  0.025767
# 4  2020-03-26  383.000000  394.700012  ...   4291225  21.500000  0.055678
#
# [5 rows x 9 columns]

# %% [markdown]
# Graph of Daily Returns

# %%
plt.figure(figsize=(15,5))
plt.plot(ndf19['return'])
plt.plot(ndf20['return'])
plt.axhline(y=0, color='red')
plt.xlabel("Time")
plt.ylabel("Daily returns")
# Out:
# Text(0, 0.5, 'Daily returns')

# %%
daily_close19 = df_in[["Adj Close_x"]]
daily_log_returns19 = np.log(daily_close19.pct_change()+1)
daily_log_returns19.fillna(0, inplace=True)
print(daily_log_returns19)
daily_close20 = df_in[["Adj Close_y"]]
daily_log_returns20 = np.log(daily_close20.pct_change()+1)
daily_log_returns20.fillna(0, inplace=True)
print(daily_log_returns20)
# Out:
#     Adj Close_x
# 0      0.000000
# 1     -0.001592
# 2     -0.000750
# 3     -0.012075
# 4      0.004640
# ..          ...
# 75    -0.021161
# 76    -0.030665
# 77    -0.010720
# 78     0.036320
# 79     0.040619
#
# [80 rows x 1 columns]
#     Adj Close_y
# 0      0.000000
# 1     -0.027118
# 2      0.047175
# 3     -0.042515
# 4      0.025441
# ..          ...
# 75     0.005956
# 76    -0.002197
# 77     0.000776
# 78     0.037487
# 79    -0.027326
#
# [80 rows x 1 columns]

# %%
daily_pct_change19 = daily_close19 / daily_close19.shift(1) - 1
daily_pct_change19.fillna(0, inplace=True)
print(daily_pct_change19)
daily_pct_change20 = daily_close20 / daily_close20.shift(1) - 1
daily_pct_change20.fillna(0, inplace=True)
print(daily_pct_change20)
# Out:
#     Adj Close_x
# 0      0.000000
# 1     -0.001590
# 2     -0.000750
# 3     -0.012002
# 4      0.004650
# ..          ...
# 75    -0.020939
# 76    -0.030200
# 77    -0.010663
# 78     0.036987
# 79     0.041455
#
# [80 rows x 1 columns]
#     Adj Close_y
# 0      0.000000
# 1     -0.026753
# 2      0.048305
# 3     -0.041624
# 4      0.025767
# ..          ...
# 75     0.005973
# 76    -0.002194
# 77     0.000776
# 78     0.038198
# 79    -0.026956
#
# [80 rows x 1 columns]

# %%
daily_pct_changen19 = daily_pct_change19.to_numpy()
daily_pct_changen20 = daily_pct_change20.to_numpy()

# %%
plt.figure(figsize=(25,15))
plt.plot(daily_pct_changen19,label='2019')
plt.plot(daily_pct_changen20,label='2020')
plt.axhline(y=0, color='red')
plt.legend(loc='upper left',fontsize=20)
plt.show()

# %%
print(daily_pct_change19.describe())
# Out:
#        Adj Close_x
# count    80.000000
# mean     -0.002125
# std       0.020389
# min      -0.082095
# 25%      -0.010694
# 50%      -0.001469
# 75%       0.006788
# max       0.064474

# %%
print(daily_pct_change20.describe())
# Out:
#        Adj Close_y
# count    80.000000
# mean      0.009436
# std       0.033973
# min      -0.048186
# 25%      -0.009297
# 50%       0.000871
# 75%       0.021734
# max       0.141474

# %%
cum_daily_return19 = (1 + daily_pct_change19).cumprod()
print(cum_daily_return19)
# Out:
#     Adj Close_x
# 0      1.000000
# 1      0.998410
# 2      0.997661
# 3      0.985688
# 4      0.990271
# ..          ...
# 75     0.800690
# 76     0.776510
# 77     0.768230
# 78     0.796645
# 79     0.829670
#
# [80 rows x 1 columns]

# %%
cum_daily_return20 = (1 + daily_pct_change20).cumprod()
print(cum_daily_return20)
# Out:
#     Adj Close_y
# 0      1.000000
# 1      0.973247
# 2      1.020260
# 3      0.977792
# 4      1.002987
# ..          ...
# 75     2.012208
# 76     2.007792
# 77     2.009351
# 78     2.086104
# 79     2.029870
#
# [80 rows x 1 columns]

# %%
cum_daily_return19.describe()
# Out:
#        Adj Close_x
# count    80.000000
# mean      0.974978
# std       0.082079
# min       0.768230
# 25%       0.895390
# 50%       0.998036
# 75%       1.040482
# max       1.082694

# %%
cum_daily_return20.describe()
# Out:
#        Adj Close_y
# count    80.000000
# mean      1.678943
# std       0.277900
# min       0.973247
# 25%       1.552110
# 50%       1.666558
# 75%       1.900487
# max       2.094156

# %%
dta = [df_in['newda'],cum_daily_return19,cum_daily_return20]
exdf = pd.concat(dta,axis=1)
exdf = exdf.rename(columns={'newda':"Date",'Adj Close_x':'2019','Adj Close_y':'2020'})
exdf
# Out:
#      Date      2019      2020
# 0   03-18  1.000000  1.000000
# 1   03-19  0.998410  0.973247
# 2   03-20  0.997661  1.020260
# 3   03-25  0.985688  0.977792
# 4   03-26  0.990271  1.002987
# ..    ...       ...       ...
# 75  09-30  0.800690  2.012208
# 76  10-01  0.776510  2.007792
# 77  10-07  0.768230  2.009351
# 78  10-09  0.796645  2.086104
# 79  10-14  0.829670  2.029870
#
# [80 rows x 3 columns]

# %%
exdf.plot(x='Date',y=["2019","2020"],figsize=(15,10))
plt.legend(fontsize=20)

# %%
ndf19['MA10'] = ndf19['Close_x'].rolling(10).mean()
ndf19['MA5'] = ndf19['Close_x'].rolling(5).mean()
ndf20['MA10'] = ndf20['Close_y'].rolling(10).mean()
ndf20['MA5'] = ndf20['Close_y'].rolling(5).mean()

# %%
plt.figure(figsize=(15,7))
plt.plot(ndf19['MA10'], label='MA10', color='red')
ndf19['MA5'].plot(label='MA5', color='blue')
ndf19['Close_x'].plot(label='Close', color='green')
plt.legend(fontsize=10)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(ndf20['MA10'], label='MA10', color='red')
ndf20['MA5'].plot(label='MA5', color='blue')
ndf20['Close_y'].plot(label='Close', color='green')
plt.legend(fontsize=10)
plt.show()
